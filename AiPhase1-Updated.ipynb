# %% [markdown]
# # Ai Project Phase-1
# This Jupiter notebook shows the description of the dataset, including the following:
#
# 1- The goal of collecting this dataset
#
# 2- The source of the dataset, include link\URL
#
# 3- General information about the dataset
#
# 4- A summary of the dataset including samples of raw dataset, graphs and tables show variables distribution, missing values and statistical summaries (mean and variance).
#
# 5-  The application of preprocessing techniques on your data with justifications variable transformatio

# %% [markdown]
# # 1- The goal of collecting this dataset

# %% [markdown]
# - To identify how do phone features affect its price.

# %% [markdown]
# # 2- The source of the dataset, include link\URL

# %% [markdown]
# - The dataset is collected from koggle.com by downloading the zip folder in which it includes a csv file, Below is a link that shows the source data.
# - Link to the dataset : https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification/code?resource=download

# %%
#Important libraries:

import numpy as np
import pandas as pd

# %%
#Read the dataset: 

data = pd.read_csv(r'train.csv')

# %% [markdown]
# # 3- General information about the dataset

# %%
# Numbers of observation:
len(data)
# Out:
# 2000

# %%
# Print the full summary of the dataset: 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# -	The dataset consists of 21 attributes, the types of the attributes are all integers and decimals, the number of observations is a two thousands.

# %% [markdown]
# Attribute Name - 	Type	- Description
# - battery_power	, Numeric , Integer	Total energy a battery can store in one time measured in mAh.
# - blue	Numeric , boolean	Has bluetooth or not.
# - clock_speed	Numeric , Decimal	Speed at which microprocessor executes instructions.
# - dual_sim , boolean , Has dual sim support or not.
# - fc	Numeric , Integer	Front Camera mega pixels.
# - four_g  , boolean,	Has 4G or not.
# - int_memory 	Numeric , Integer	Internal Memory in Gigabytes.
# - m_dep	Numeric , Decimal	Mobile Depth in cm.
# - mobile_wt	Numeric , Integer	Weight of mobile phone.
# - n_cores	Numeric , Integer	Number of cores of processor.
# - pc	Numeric , Integer	Primary Camera mega pixels.
# - px_height	Numeric , Integer	Pixel Resolution Height.
# - px_width	Numeric , Integer	Pixel Resolution Width.
# - ram	Numeric , Integer	Random Access Memory in Megabytes.
# - sc_h	Numeric , Integer	Screen Height of mobile in cm.
# - sc_w 	Numeric , Integer	Screen Width of mobile in cm.
# - talk_time	Numeric , Integer	longest time that a single battery charge will last when you are.
# - three_g , boolean,	Has 3G or not.
# - touch_screen	,boolean ,	Has touch screen or not.
# - wifi	Numeric , boolean,	Has wifi or not.
# - Price_Range	Numeric , Integer	This is the Target variable with value of 0: (Low Cost), 1: (Medium Cost), 2: (High Cost), and 3: (Very High Cost)

# %% [markdown]
# # 4- A summary of the dataset including samples of raw dataset, graphs and tables show variables distribution, missing values and statistical summaries (mean and variance).

# %% [markdown]
# ## 4.1 Samples of raw dataset:

# %%
# Samples of raw dataset (The head of the dataset):
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# Samples of raw dataset (The Tail of the dataset):
data.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
# Random sample rows: 
rowsSample = data.sample(n = 8)
rowsSample
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 596            1175     0          0.6         0  10       0          25
# 1139            831     0          2.4         0  10       0          55
# 390            1836     1          1.7         1   3       0          26
# 913            1763     0          2.9         1   1       1          53
# 1788           1424     0          0.5         1  16       1          23
# 1260           1097     0          1.4         0   0       0          60
# 1646            855     1          0.5         0   2       1          59
# 358            1394     1          0.9         1  10       1          62
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 596     0.1        145        2  ...        137      1501  3153     9     4
# 1139    0.5         86        6  ...        172      1239  1075    12    11
# 390     0.1        134        6  ...        408      1139  3097     5     0
# ...

# %% [markdown]
# ## 4.2 Graphs and Tables show variables distribution:

# %%
# Important Data visualizations libraries: 
# Matplotlib is a comprehensive library for creating interactive visualizations and Seaborn based on matplotlib.
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.jointplot(data = data , dropna = True)
plt.show()

# %% [markdown]
# In this graph, we can see the scatter of the dataset attributes.

# %%
sns.displot(data, x="battery_power")

# %% [markdown]
# This graph represents battery power values and the count of each of them, the battery power starts from 600 to 2000

# %%
sns.jointplot(x='battery_power',y='price_range',data=data ,color='red',kind='kde');

# %% [markdown]
# In this graph, we can see How does battery power is affected by the price

# %%
    print(data['battery_power'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        842
# 1       1021
# 2        563
# 3        615
# 4       1821
#         ...
# 1995     794
# 1996    1965
# 1997    1911
# 1998    1512
# 1999     510
# Name: battery_power, Length: 2000, dtype: int64>

# %%
sns.countplot(data=data, x="blue",hue="blue")
# Out:
# <Axes: xlabel='blue', ylabel='count'>

# %% [markdown]
# In this graph, we can see the count of the devices that have Bluetooth ( 1 means has Bluetooth, 0 means no Bluetooth)

# %%
    print(data['blue'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    0
# 1998    0
# 1999    1
# Name: blue, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="clock_speed")

# %% [markdown]
# This graph represents clock_speed values and the count of each of them, the clock speed starts from 0,5 to 3.0

# %%
sns.jointplot(x='clock_speed',y='price_range',data=data ,color='blue',kind='hex');

# %% [markdown]
# This graph represents How does clock speed is affected by the price, the clock speed starts from 0.5 to 3.0

# %%
    print(data['clock_speed'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       2.2
# 1       0.5
# 2       0.5
# 3       2.5
# 4       1.2
#        ...
# 1995    0.5
# 1996    2.6
# 1997    0.9
# 1998    0.9
# 1999    2.0
# Name: clock_speed, Length: 2000, dtype: float64>

# %%
sns.countplot(data=data, x="dual_sim",hue="dual_sim")
# Out:
# <Axes: xlabel='dual_sim', ylabel='count'>

# %% [markdown]
# In this graph, we can see the count of the devices that have dual_sim ( 1 means has dual sim, 0 means no dual_sim)

# %%
    print(data['dual_sim'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 1995    1
# 1996    1
# 1997    1
# 1998    0
# 1999    1
# Name: dual_sim, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="fc")

# %% [markdown]
# This graph represents fc values and the count of each of them, the fc starts from 0.0 to 17.5

# %%
    print(data['fc'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        0
# 2        2
# 3        0
# 4       13
#         ..
# 1995     0
# 1996     0
# 1997     1
# 1998     4
# 1999     5
# Name: fc, Length: 2000, dtype: int64>

# %%
sns.countplot(data=data, x="four_g",hue= 'four_g')
# Out:
# <Axes: xlabel='four_g', ylabel='count'>

# %% [markdown]
# This graph represent the count of the devices that have four_g ( 1 means has four_g, 0 means no four_g)

# %%
    print(data['four_g'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1995    1
# 1996    0
# 1997    1
# 1998    1
# 1999    1
# Name: four_g, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="int_memory")

# %% [markdown]
# This graph represents int_memory values and the count of each of them, the int_memory starts from 0 to 60

# %%
    print(data['int_memory'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        7
# 1       53
# 2       41
# 3       10
# 4       44
#         ..
# 1995     2
# 1996    39
# 1997    36
# 1998    46
# 1999    45
# Name: int_memory, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="m_dep")

# %% [markdown]
# This graph represents m_dep values and the count of each of them, the m_dep starts from 0.2 to 1.0

# %%
    print(data['m_dep'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0.6
# 1       0.7
# 2       0.9
# 3       0.8
# 4       0.6
#        ...
# 1995    0.8
# 1996    0.2
# 1997    0.7
# 1998    0.1
# 1999    0.9
# Name: m_dep, Length: 2000, dtype: float64>

# %%
sns.displot(data, x="mobile_wt")

# %% [markdown]
# This graph represents How mobile_wt values and the count of each of them, the mobile_wt starts from 0.0 to 17.5

# %%
    print(data['mobile_wt'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       188
# 1       136
# 2       145
# 3       131
# 4       141
#        ...
# 1995    106
# 1996    187
# 1997    108
# 1998    145
# 1999    168
# Name: mobile_wt, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="n_cores")

# %% [markdown]
# This graph represents n_cores values and the count of each of them, the n_cores starts from 1 to 8

# %%
    print(data['n_cores'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       2
# 1       3
# 2       5
# 3       6
# 4       2
#        ..
# 1995    6
# 1996    4
# 1997    8
# 1998    5
# 1999    6
# Name: n_cores, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="pc")

# %% [markdown]
# This graph represents pc values and the count of each of them, the pc starts from 0.0 to 20.0

# %%
    print(data['pc'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        2
# 1        6
# 2        6
# 3        9
# 4       14
#         ..
# 1995    14
# 1996     3
# 1997     3
# 1998     5
# 1999    16
# Name: pc, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="px_height")

# %% [markdown]
# This graph represents px_height values and the count of each of them, the px_height starts from 0 to 2000

# %%
    print(data['px_height'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0         20
# 1        905
# 2       1263
# 3       1216
# 4       1208
#         ...
# 1995    1222
# 1996     915
# 1997     868
# 1998     336
# 1999     483
# Name: px_height, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="px_width")

# %% [markdown]
# This graph represents px_width values and the count of each of them, the px_width starts from 600 to 2000

# %%
    print(data['px_width'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        756
# 1       1988
# 2       1716
# 3       1786
# 4       1212
#         ...
# 1995    1890
# 1996    1965
# 1997    1632
# 1998     670
# 1999     754
# Name: px_width, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="ram")

# %% [markdown]
# This graph represents ram values and the count of each of them , the ram starts from 500 to 4000

# %%
sns.jointplot(x='ram',y='price_range',data=data ,color='red',kind='kde');

# %% [markdown]
# This graph represents How ram is affected by the price

# %%
    print(data['ram'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       2549
# 1       2631
# 2       2603
# 3       2769
# 4       1411
#         ...
# 1995     668
# 1996    2032
# 1997    3057
# 1998     869
# 1999    3919
# Name: ram, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="sc_h")

# %% [markdown]
# This graph represents How sc_h values and the count of each of them, the sc_h starts from 6 to 18

# %%
    print(data['sc_h'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        9
# 1       17
# 2       11
# 3       16
# 4        8
#         ..
# 1995    13
# 1996    11
# 1997     9
# 1998    18
# 1999    19
# Name: sc_h, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="sc_w")

# %% [markdown]
# This graph represents How sc_w values the count of each of them, the sc_w starts from 0.0 to 17.5

# %%
    print(data['sc_w'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        7
# 1        3
# 2        2
# 3        8
# 4        2
#         ..
# 1995     4
# 1996    10
# 1997     1
# 1998    10
# 1999     4
# Name: sc_w, Length: 2000, dtype: int64>

# %%
sns.displot(data, x="talk_time")

# %% [markdown]
# This graph represents talk_time values and the count of each of them, the talk_time starts from 2.5 to 20

# %%
    print(data['talk_time'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       19
# 1        7
# 2        9
# 3       11
# 4       15
#         ..
# 1995    19
# 1996    16
# 1997     5
# 1998    19
# 1999     2
# Name: talk_time, Length: 2000, dtype: int64>

# %%
sns.countplot(data, x="three_g", hue='three_g')
# Out:
# <Axes: xlabel='three_g', ylabel='count'>

# %% [markdown]
# This graph represents three-g availability in the mobile device and the count of each of them ( 1 represents have three_g , 0 represents no three_g in the device)

# %%
    print(data['three_g'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# Name: three_g, Length: 2000, dtype: int64>

# %%
sns.countplot(data, x="touch_screen",hue='touch_screen')
# Out:
# <Axes: xlabel='touch_screen', ylabel='count'>

# %% [markdown]
# This graph represents touch-screen availability in the mobile device and the count of each of them ( 1 represents have three_g , 0 represents no three_g)

# %%
    print(data['touch_screen'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# Name: touch_screen, Length: 2000, dtype: int64>

# %%
sns.countplot(data, x="wifi",hue='wifi')
# Out:
# <Axes: xlabel='wifi', ylabel='count'>

# %% [markdown]
# This graph represents wifi availability in the mobile device and the count of each of them, ( 1 represents have wifi, 0 represents no wifi)

# %%
    print(data['wifi'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    1
# 1997    0
# 1998    1
# 1999    1
# Name: wifi, Length: 2000, dtype: int64>

# %%
sns.countplot(data, x="price_range",hue='price_range' )
# Out:
# <Axes: xlabel='price_range', ylabel='count'>

# %% [markdown]
# This graph represents price_range in the dataset and the count of each of them

# %%
    print(data['price_range'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64>

# %% [markdown]
# ## 4.3 Missing values:

# %%
data.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ### No Missing Values

# %% [markdown]
# ## 4.4 Statistical summaries (mean and variance).¶

# %%
# Mean for all attributes:
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# This table represents a statistical description of all dataset attributes including mean, max, min

# %%
# Variance of the dataset 
print(np.var(data))
# Out:
# battery_power    1.929918e+05
# blue             2.499750e-01
# clock_speed      6.655299e-01
# dual_sim         2.499097e-01
# fc               1.883871e+01
# four_g           2.495377e-01
# int_memory       3.291023e+02
# m_dep            8.314194e-02
# mobile_wt        1.252509e+03
# n_cores          5.231580e+00
# pc               3.675753e+01
# px_height        1.968429e+05
# px_width         1.867030e+05
# ram              1.176055e+06
# sc_h             1.774256e+01
# sc_w             1.896871e+01
# talk_time        2.983988e+01
# three_g          1.816178e-01
# touch_screen     2.499910e-01
# wifi             2.499510e-01
# price_range      1.250000e+00
# dtype: float64

# %% [markdown]
# # 5- The application of preprocessing techniques on our data with justifications variable transformatio

# %% [markdown]
# -	Data preprocessing is a critical phase in data analysis, it leads to an enhanced result. We applied some data processing technique to our dataset to have a better result from the model, After analyzing our dataset it was clear to us that it did not require much cleaning up, just some dealing with missing values if found. Additionally, we removed any duplicate entries and performed normalization.
#
# -	Before getting started we checked the number of observation in the dataset, and then printed them to view them before the preprocessing.

# %%
#Print some part of the data
data.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %% [markdown]
# ## Dealing with Missing Values:
# We checked if our dataset contains any missing values, and based on the results of that we found that our dataset was full with no missing values. Since we didn’t have missing values, we didn’t need to remove any subsets of the dataset.

# %%
#check columns with missing values
data.columns[data.isnull().any()]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# another code to assure same result: 
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ## Dealing with duplicated rows:
# We checked if our dataset contains any duplicate rows, and based on the results of that we found that our dataset had no duplicated rows. Since we didn’t any, we didn’t need to remove any subsets of the dataset.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Min max normalization:
# For data transformation we applied the min max normalization to rescale the data, min max normalization guarantees all features have the exact same scale.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data=pd.DataFrame(scaler.fit_transform(data),
            columns=data.columns, index=data.index) 
print(data.head(4))
# Out:
#    battery_power  blue  clock_speed  dual_sim        fc  four_g  int_memory  \
# 0       0.227789   0.0         0.68       0.0  0.052632     0.0    0.080645
# 1       0.347361   1.0         0.00       1.0  0.000000     1.0    0.822581
# 2       0.041416   1.0         0.00       1.0  0.105263     1.0    0.629032
# 3       0.076152   1.0         0.80       0.0  0.000000     0.0    0.129032
#
#       m_dep  mobile_wt   n_cores  ...  px_height  px_width       ram  \
# 0  0.555556   0.900000  0.142857  ...   0.010204  0.170895  0.612774
# 1  0.666667   0.466667  0.285714  ...   0.461735  0.993324  0.634687
# 2  0.888889   0.541667  0.571429  ...   0.644388  0.811749  0.627205
# 3  0.777778   0.425000  0.714286  ...   0.620408  0.858478  0.671566
#
#        sc_h      sc_w  talk_time  three_g  touch_screen  wifi  price_range
# 0  0.285714  0.388889   0.944444      0.0           0.0   1.0     0.333333
# 1  0.857143  0.166667   0.277778      1.0           1.0   0.0     0.666667
# ...

# %%
# Visual Clarification of our dataset after applying the normaliztion: 
sns.jointplot(data = data , dropna = True)
plt.show()

# %% [markdown]
# This graph represents the attributes scatter after normalization
